# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Loading the Boston House Pricing Dataset

# %%
boston = pd.read_csv(r'C:\Users\chhay\OneDrive\Desktop\Housing Data.csv')

# %%
boston.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'STAT', 'MEDV'],
#       dtype='object')

# %%
print(boston.columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'STAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# ## Preparing The Dataset

# %%
dataset=pd.DataFrame(boston,columns=boston.columns)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.575  65.2  4.0901    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  6.575  65.2  4.0902    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.575  65.2  4.0903    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  6.575  65.2  4.0904    3  222     18.7
#
#         B  STAT  MEDV
# 0  396.90  4.98  24.0
# 1  396.90  9.14  21.6
# 2  392.83  4.03  34.7
# 3  394.63  2.94  33.4
# 4  396.90  5.33  36.2

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.575  65.2  4.0901    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  6.575  65.2  4.0902    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.575  65.2  4.0903    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  6.575  65.2  4.0904    3  222     18.7
#
#         B  STAT  MEDV
# 0  396.90  4.98  24.0
# 1  396.90  9.14  21.6
# 2  392.83  4.03  34.7
# 3  394.63  2.94  33.4
# 4  396.90  5.33  36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  STAT     506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.282053
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.700239
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.613500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.628854    3.779886    9.549407  408.237154   18.455534  356.674032
# std     28.116136    2.097301    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.150000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.116700   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#              STAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
## Check the missing Values
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# STAT       0
# MEDV       0
# dtype: int64

# %%
### EXploratory Data Analysis
## Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.218460  0.352348
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.314850 -0.571137
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.389103  0.642537
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.092567  0.086095
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.300255  0.730653
# RM      -0.218460  0.314850 -0.389103  0.092567 -0.300255  1.000000 -0.238287
# AGE      0.352348 -0.571137  0.642537  0.086095  0.730653 -0.238287  1.000000
# DIS     -0.378184  0.670600 -0.702592 -0.097601 -0.766429  0.200421 -0.748438
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.207633  0.455185
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.289112  0.504840
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356590  0.262318
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.126970 -0.273066
# STAT     0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.611166  0.600036
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.691853 -0.373841
#
#               DIS       RAD       TAX   PTRATIO         B      STAT      MEDV
# CRIM    -0.378184  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.670600 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.702592  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.097601 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.766429  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.200421 -0.207633 -0.289112 -0.356590  0.126970 -0.611166  0.691853
# AGE     -0.748438  0.455185  0.504840  0.262318 -0.273066  0.600036 -0.373841
# DIS      1.000000 -0.490934 -0.528769 -0.233532  0.289630 -0.491199  0.243705
# RAD     -0.490934  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.528769  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.233532  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.289630 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# STAT    -0.491199  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.243705 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.218460  0.352348
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.314850 -0.571137
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.389103  0.642537
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.092567  0.086095
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.300255  0.730653
# RM      -0.218460  0.314850 -0.389103  0.092567 -0.300255  1.000000 -0.238287
# AGE      0.352348 -0.571137  0.642537  0.086095  0.730653 -0.238287  1.000000
# DIS     -0.378184  0.670600 -0.702592 -0.097601 -0.766429  0.200421 -0.748438
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.207633  0.455185
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.289112  0.504840
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356590  0.262318
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.126970 -0.273066
# STAT     0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.611166  0.600036
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.691853 -0.373841
#
#               DIS       RAD       TAX   PTRATIO         B      STAT      MEDV
# CRIM    -0.378184  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.670600 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.702592  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.097601 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.766429  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.200421 -0.207633 -0.289112 -0.356590  0.126970 -0.611166  0.691853
# AGE     -0.748438  0.455185  0.504840  0.262318 -0.273066  0.600036 -0.373841
# DIS      1.000000 -0.490934 -0.528769 -0.233532  0.289630 -0.491199  0.243705
# RAD     -0.490934  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.528769  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.233532  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.289630 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# STAT    -0.491199  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.243705 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.scatter(dataset['CRIM'],dataset['MEDV'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['RM'],dataset['MEDV'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="RM",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x="STAT",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='STAT', ylabel='MEDV'>

# %%
sns.regplot(x="CHAS",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>

# %%
sns.regplot(x="PTRATIO",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='MEDV'>

# %%
## Independent and Dependent features

X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.575  65.2  4.0901    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  6.575  65.2  4.0902    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.575  65.2  4.0903    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  6.575  65.2  4.0904    3  222     18.7
#
#         B  STAT
# 0  396.90  4.98
# 1  396.90  9.14
# 2  392.83  4.03
# 3  394.63  2.94
# 4  396.90  5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.575  65.2  4.0905    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B   STAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13
# ..       ...     ...    ...
# 106     20.9  395.67  18.66
# 270     18.6  388.65  13.00
# 348     17.0  390.94   5.99
# 435     20.2  109.85  23.27
# 102     20.9   70.80  10.63
#
# [354 rows x 13 columns]

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B   STAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# 491     20.1  390.11  18.07
# 72      19.2  390.91   5.52
# 452     20.2  385.09  17.27
# ..       ...     ...    ...
# 441     20.2  385.96  19.52
# 23      21.0  394.54  19.88
# 225     17.4  382.00   4.63
# 433     20.2  100.19  16.22
# 447     20.2  388.52  16.44
#
# [152 rows x 13 columns]

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [-1.12810729  0.89214253  0.3381902   0.81627828 -1.86768052  2.843027
#  -0.26634055 -3.05154931  2.12188041 -1.44835472 -2.06406674  1.02045888
#  -3.90971611]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.70932714, 36.58484709, 15.44217432, 25.29825889, 18.82049333,
#        23.14153719, 17.34738665, 14.07241931, 23.08872973, 20.61991281,
#        24.87100905, 18.41200727, -6.8307293 , 21.71809849, 19.19784397,
#        26.13802111, 20.32903196,  5.70385625, 40.5226295 , 17.55301783,
#        27.42627816, 30.25967576, 10.88862543, 23.9771711 , 18.10140741,
#        16.04607437, 23.09511126, 14.48154587, 22.348122  , 19.33371834,
#        22.28988456, 25.10352429, 25.26089007, 18.57581818, 16.67365086,
#        17.46292283, 29.60900804, 20.07983033, 23.85800003, 24.74041654,
#        13.96599418, 31.94831858, 42.71727993, 17.54990687, 27.03093987,
#        17.24279592, 13.79677288, 25.9621811 , 20.32758603, 30.08448949,
#        21.22412939, 34.1001112 , 15.53817349, 26.08540477, 39.30621327,
#        22.91776309, 18.94519546, 33.22308472, 24.76415573, 12.80881693,
#        22.46606012, 30.76773666, 31.59242837, 16.2683243 , 20.87049336,
#        16.63397137, 20.36302863, 26.13811325, 31.20648793, 11.97279805,
#        20.3425352 , 27.54355704, 10.93028653, 16.72227327, 23.90588254,
#         5.26976068, 21.49433952, 41.49868172, 18.21007335,  9.55198489,
#        21.10947115, 13.07236733, 21.64746219,  9.46672649, 23.1055371 ,
#        31.92928058, 19.08876397, 25.48751519, 29.426281  , 20.12373163,
#        25.56843688,  5.47146048, 20.21545947, 14.95836728, 14.31438241,
#        20.89305927, 24.94116838, -0.31346984, 13.65180213, 15.73560059,
#        22.02251028, 24.58467481, 10.82500753, 19.61154411, 23.58704101,
#        12.12354128, 18.46084459, 25.34718252, 20.75523624, 24.69112708,
#         7.5482056 , 19.03559768, 21.72205032, 27.28611568, 32.15814693,
#        15.26060218, 34.33334364, 12.92182978, 21.05062546, 28.52013936,
#        15.78360485, 24.67296179,  3.27786642, 23.9576078 , 25.66191869,
#        23.03758433, 25.33523141, 33.37305395, 20.51754478, 38.41153845,
#        14.03125536, 25.08859147, 17.76697753, 20.68455876,  9.76318399,
#        21.12585078, 22.22741929, 32.41986581, 31.54109238, 15.40652748,
#        16.79651316, 29.02964626, 25.13408794, 16.78432186,  6.0926161 ,
#        26.77690168, 23.26365291, 17.34862783, 13.34832905, 39.84448127,
#        16.64746059, 18.24559683])

# %% [markdown]
# ## Assumptions

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
## Residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173    -5.109327
# 274    -4.184847
# 491    -1.842174
# 72     -2.498259
# 452    -2.720493
#          ...
# 441    -0.248628
# 23      1.151671
# 225    10.155519
# 433    -2.347461
# 447    -5.645597
# Name: MEDV, Length: 152, dtype: float64

# %%
## Plot this residuals 

sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.164645184557191
# 21.473630838116343
# 4.63396491550339

# %% [markdown]
# ## R square and adjusted R square

# %% [markdown]
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7118140016266266

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6846660452581204

# %% [markdown]
# ## Creating a Pipeline

# %%
from sklearn.impute import SimpleImputer           #this method automatically fill missing values with median of all coloumns
imputer = SimpleImputer(strategy ='median')
imputer.fit(dataset)
# Out:
# SimpleImputer(strategy='median')

# %%
X= imputer.transform(dataset) 
dataset_tr = pd.DataFrame(X , columns=dataset.columns)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([('imputer' , SimpleImputer(strategy = 'median')) , ('std_scaler', StandardScaler())])

# %%
dataset_num_tr = my_pipeline.fit_transform(dataset_tr)

# %%
dataset_num_tr.shape
# Out:
# (506, 14)

# %% [markdown]
# ## Model Selection

# %%
dataset_labels=dataset["MEDV"].copy()

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model= LinearRegression()
#model = DecisionTreeRegressor()
model= RandomForestRegressor()
model.fit(dataset_num_tr , dataset_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = dataset.iloc[:5]

# %%
some_labels = dataset_labels.iloc[:5]

# %%
prepared_data = my_pipeline.fit_transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([13.325,  9.671, 29.774, 27.918, 32.01 ])

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
housing_prediction = model.predict(dataset_num_tr)
lin_mse = mean_squared_error(dataset_labels , housing_prediction)
lin_rmse = np.sqrt(lin_mse)
lin_mse
# Out:
# 0.004078019762845937

# %%
lin_rmse
# Out:
# 0.0638593749017788

# %% [markdown]
# ## Testing MOdel on the data

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1 , test_size = 0.2, random_state=42)

# %%
for train_index , test_index in split.split(dataset,dataset['CHAS']):
    strat_train_set = dataset.loc[train_index]
    strat_test_set = dataset.loc[test_index]

# %%
X_test = strat_test_set.drop("MEDV" , axis=1)
Y_test = strat_test_set["MEDV"]
X_test_prepared = my_pipeline.fit_transform(X_test)
final_prediction = regression.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test , final_prediction)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 4.147145085296264

# %%
input = np.array([[-0.5 , 3 , -1 , -0.2 , -1.4 , -0.2 , -1.3 , 2.6 , -1 , -0.5, -0.9 , 0.4 , -0.86]])

# %%
regression.predict(input)
# Out:
# array([24.44371287])

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## Prediction
pickled_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
